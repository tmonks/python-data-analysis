# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
z = np.random.randint(0,10, size=(20,20))

# %%
fig, ax = plt.subplots()
ax.matshow(z, cmap='viridis')

# %% [markdown]
# ## More Information
#
# - [Matplotlib Annotated Heatmap](https://matplotlib.org/stable/gallery/images_contours_and_fields/image_annotated_heatmap.html)
# - [Matrix values and colormap](https://stackoverflow.com/questions/40887753/display-matrix-values-and-colormap)
