# %%
import pandas as pd

# %%
df = pd.read_csv('data/titanic.csv')

# %% [markdown]
# Quick histogram of a column

# %%
df.age.hist(bins=20)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Horizontal bar of value counts

# %%
df['class'].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Bar chart showing the mean survival rate for males & females

# %%
df.groupby('sex')['survived'].mean()
# Out:
# sex
# female    0.778802
# male      0.180488
# Name: survived, dtype: float64

# %%
df.groupby('sex')['survived'].mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='sex'>
